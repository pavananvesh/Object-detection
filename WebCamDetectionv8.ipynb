# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting hydra-core>=1.2.0
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 8)) (4.8.1.78)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 12)) (1.13.1)
# Requirement already satisfied: torch>=1.7.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 13)) (2.3.1)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 14)) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 15)) (4.66.4)
# Collecting ultralytics==8.0.0
#   Downloading ultralytics-8.0.0-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 20.4 MB/s eta 0:00:01
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 19)) (2.17.0)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      |████████████████████████████████| 177 kB 22.2 MB/s eta 0:00:01
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl (13.4 MB)
#      |████████████████████████████████| 13.4 MB 12.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.1.4 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 28)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 29)) (0.13.2)
# Requirement already satisfied: ipython in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 43)) (8.18.1)
# Requirement already satisfied: psutil in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 44)) (6.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 45)) (0.1.1.post2209072238)
# Requirement already satisfied: GitPython>=3.1.24 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 51)) (3.1.43)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 44.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from hydra-core>=1.2.0->-r requirements.txt (line 5)) (24.0)
# Collecting omegaconf<2.4,>=2.2
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->-r requirements.txt (line 11)) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->-r requirements.txt (line 11)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->-r requirements.txt (line 11)) (1.26.19)
# Requirement already satisfied: networkx in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (3.2.1)
# Requirement already satisfied: fsspec in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (2023.10.0)
# Requirement already satisfied: filelock in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (3.13.1)
# Requirement already satisfied: jinja2 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (3.1.2)
# Requirement already satisfied: sympy in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (1.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from torch>=1.7.0->-r requirements.txt (line 13)) (4.11.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (3.6)
# Requirement already satisfied: absl-py>=0.4 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (1.64.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (3.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (70.2.0)
# Requirement already satisfied: six>1.9 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (1.16.0)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 19)) (4.21.12)
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting imageio>=2.33
#   Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#      |████████████████████████████████| 313 kB 20.0 MB/s eta 0:00:01
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.7.2-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 51.8 MB/s eta 0:00:01
# Requirement already satisfied: tzdata>=2022.7 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from pandas>=1.1.4->-r requirements.txt (line 28)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from pandas>=1.1.4->-r requirements.txt (line 28)) (2024.1)
# Requirement already satisfied: exceptiongroup in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (1.2.0)
# Requirement already satisfied: stack-data in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (3.0.43)
# Requirement already satisfied: pexpect>4.3 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (2.17.2)
# Requirement already satisfied: traitlets>=5 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (5.14.2)
# Requirement already satisfied: decorator in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from ipython->-r requirements.txt (line 43)) (5.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from GitPython>=3.1.24->-r requirements.txt (line 51)) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.24->-r requirements.txt (line 51)) (5.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->-r requirements.txt (line 6)) (3.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 43)) (0.8.4)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 19)) (7.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 43)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 43)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 19)) (2.1.3)
# Requirement already satisfied: pure-eval in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->-r requirements.txt (line 43)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->-r requirements.txt (line 43)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->-r requirements.txt (line 43)) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/kenny/Library/Python/3.9/lib/python/site-packages (from sympy->torch>=1.7.0->-r requirements.txt (line 13)) (1.3.0)
# Building wheels for collected packages: antlr4-python3-runtime, filterpy
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144552 sha256=f839b307419b9f3eb7e52e20463650155d1592337cae5ae00334451c574735e5
#   Stored in directory: /Users/kenny/Library/Caches/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110459 sha256=b61bedc14c07ac10bf61441c8f4081535acc988c7417d29166ab8ee17773eb2f
#   Stored in directory: /Users/kenny/Library/Caches/pip/wheels/53/e6/de/a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built antlr4-python3-runtime filterpy
# Installing collected packages: antlr4-python3-runtime, omegaconf, tifffile, lazy-loader, imageio, hydra-core, ultralytics, scikit-image, filterpy
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.50
#     Uninstalling ultralytics-8.2.50:
#       Successfully uninstalled ultralytics-8.2.50
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yolov5 7.0.13 requires ultralytics>=8.0.100, but you have ultralytics 8.0.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 filterpy-1.4.5 hydra-core-1.3.2 imageio-2.34.2 lazy-loader-0.4 omegaconf-2.3.0 scikit-image-0.24.0 tifffile-2024.7.2 ultralytics-8.0.0
# WARNING: You are using pip version 21.2.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
from ultralytics.yolo.v8.detect.predict import DetectionPredictor

import cv2

model = YOLO("yolov8x.pt")
results = model.predict(source='1',show = True)
print(results)
